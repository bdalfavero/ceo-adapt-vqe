# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("xxz_parallel_times.csv", index_col=None)
print(df.head())
# Out:
#    Unnamed: 0  l  ncores      avg_time
# 0           0  4       1  4.231017e+08
# 1           1  4       2  4.220339e+08
# 2           2  4       4  4.159370e+08
# 3           3  4       6  2.811602e+08
# 4           4  6       1  3.977339e+09

# %%
fig, ax = plt.subplots()

colors = ['k', 'r', 'g']
for i, l in enumerate(np.unique(df["l"])):
    print(f"l = {l}")
    df_l = df[df["l"] == l]
    ax.plot(df_l["ncores"], df_l["avg_time"], '.', color=colors[i], label=f"{l:d}")
ax.legend()
ax.set_xlabel("Number of cores")
ax.set_ylabel("Time (ns)")
# Out:
# l = 4
# l = 6
# l = 8
# Text(0, 0.5, 'Time (ns)')
